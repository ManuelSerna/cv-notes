# %%
# Naive Histogram Code Demo

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import histogram as h

# %%
filename = 'seeds.jpg'
#filename = 'bird.jpg'

# %%
# Create image histogram
histogram = h.Histogram(filename=filename)

# %%
histogram.compute(normalized=True)

# %%
# Show original image and histogram
# TODO: plot og img and hist
histogram.plot()

# %%
# Perform histogram equalization
histogram.equalize()
equalized_img = histogram.apply_to_img()
histogram.compute(img=equalized_img, normalized=True)

# %%
# Show image and histogram after histogram equalization
histogram.plot(img=equalized_img)
